# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
ds=pd.read_csv('RTA Dataset.csv')

# %%
ds.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
ds.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
ds.drop(['Fitness_of_casuality', 'Time', 'Service_year_of_vehicle', 'Work_of_casuality', 'Defect_of_vehicle'], axis=1, inplace=True, errors='ignore')

# %%
ds['Educational_level'] = ds['Educational_level'].fillna('Unkown')
ds['Type_of_vehicle']=ds['Type_of_vehicle'].fillna('Unknow')
ds['Owner_of_vehicle']=ds['Owner_of_vehicle'].fillna('Unknow')
ds['Area_accident_occured']=ds['Area_accident_occured'].fillna('Other')
ds['Lanes_or_Medians']=ds['Lanes_or_Medians'].fillna('Other')
ds['Types_of_Junction']=ds['Types_of_Junction'].fillna('No juncation')
ds['Vehicle_movement']=ds['Vehicle_movement'].fillna('Unknow')
ds['Type_of_collision']=ds['Type_of_collision'].fillna('Unknow')
ds['Road_surface_type']=ds['Road_surface_type'].fillna('Other')

# %%
ds['Vehicle_driver_relation']=ds['Vehicle_driver_relation'].fillna('Unknow')

# %%
ds['Driving_experience']=ds['Driving_experience'].fillna('Unknow')
ds['Road_allignment']=ds['Road_allignment'].fillna('Unknow')

# %%
ds.isnull().sum()
# Out:
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
ds.duplicated().sum()
# Out:
# np.int64(0)

# %%
ds.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
ds.shape
# Out:
# (12316, 27)

# %%
ds['Accident_severity'].value_counts()
# Out:
# Accident_severity
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: count, dtype: int64

# %%
sns.countplot(x=ds['Accident_severity'])
# Out:
# <Axes: xlabel='Accident_severity', ylabel='count'>

# %%
sns.scatterplot(x=ds['Number_of_vehicles_involved'],y=ds['Number_of_casualties'],color='orange')
# Out:
# <Axes: xlabel='Number_of_vehicles_involved', ylabel='Number_of_casualties'>

# %%
sns.histplot(ds['Sex_of_driver'])
# Out:
# <Axes: xlabel='Sex_of_driver', ylabel='Count'>

# %%
sns.countplot(ds['Day_of_week'], palette="tab10")
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_11980\789874285.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ds['Day_of_week'], palette="tab10")
# <Axes: xlabel='count', ylabel='Day_of_week'>

# %%
sns.countplot(ds['Age_band_of_driver'], palette="tab10")
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_11980\1311855298.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ds['Age_band_of_driver'], palette="tab10")
# <Axes: xlabel='count', ylabel='Age_band_of_driver'>

# %%
sns.countplot(ds['Educational_level'], palette="tab10")
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_11980\65702938.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ds['Educational_level'], palette="tab10")
# <Axes: xlabel='count', ylabel='Educational_level'>

# %%
sns.jointplot(x='Road_surface_conditions',y='Weather_conditions',data=ds)

# %%
print(ds.columns,label)
# Out:
# Index(['Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Area_accident_occured',
#        'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction',
#        'Road_surface_type', 'Road_surface_conditions', 'Light_conditions',
#        'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty',
#        'Age_band_of_casualty', 'Casualty_severity', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')
